# %%
import numpy as np
import pandas as pd

# %%
data = {
    "Name" : ["John","Kinny","pointer"],
    "Age" : [24,53,34],
    "Salary": [3533,2443,56466],
    "Work Exprience" : [2,3,5,]
}

# %%
df = pd.DataFrame(data)

# %%
df
# Out:
#       Name  Age  Salary  Work Exprience
# 0     John   24    3533               2
# 1    Kinny   53    2443               3
# 2  pointer   34   56466               5

# %%
df.drop(["Name","Age"],axis = 1)  #Now this removing Function
# Out:
#    Salary  Work Exprience
# 0    3533               2
# 1    2443               3
# 2   56466               5

# %%
df
# Out:
#       Name  Age  Salary  Work Exprience
# 0     John   24    3533               2
# 1    Kinny   53    2443               3
# 2  pointer   34   56466               5

# %%
i = df.loc[1] ["Work Exprience"]

# %%
print(i)
# Out:
# 3

# %%
df.loc[[1,2]]
# Out:
#       Name  Age  Salary  Work Exprience
# 1    Kinny   53    2443               3
# 2  pointer   34   56466               5

# %%
df
# Out:
#       Name  Age  Salary  Work Exprience
# 0     John   24    3533               2
# 1    Kinny   53    2443               3
# 2  pointer   34   56466               5

# %%
df["Designation"] = ["Hr","sbi","ubi"]

# %%
df
# Out:
#       Name  Age  Salary  Work Exprience Designation
# 0     John   24    3533               2          Hr
# 1    Kinny   53    2443               3         sbi
# 2  pointer   34   56466               5         ubi

# %%
df[(df["Age"] > 30) & (df["Work Exprience"] < 4)]
# Out:
#     Name  Age  Salary  Work Exprience Designation
# 1  Kinny   53    2443               3         sbi
