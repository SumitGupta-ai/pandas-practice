# %%
import numpy as np
import pandas as pd

# %%
lables = ["a","b","c"]
my_list = [10,20,30]
arr = np.array([10,20,30])
dic = {1:10,2:20,3:30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(my_list,index=lables)
# Out:
# a    10
# b    20
# c    30
# dtype: int64

# %%
pd.Series(arr)
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
pd.Series(dic)
# Out:
# 1    10
# 2    20
# 3    30
# dtype: int64

# %%
data = {
    "Name": ["jonny", "Anna","Rahul", "krishna"],
    "Age": [23,45,34,24],
    "City": ["Delhi","Mumbhai","Banglore","New york"],
    "Salary": [65000,4500,7800,45820]
}

# %%
df2 = pd.DataFrame(data)
print(df2)
# Out:
#       Name  Age      City  Salary
# 0    jonny   23     Delhi   65000
# 1     Anna   45   Mumbhai    4500
# 2    Rahul   34  Banglore    7800
# 3  krishna   24  New york   45820

# %%
dataa = [
    ["john", 24, "New york", 65412],
    ["Noman", 38, "USA", 78400],
    ["Dennis Retchie", 90, "South africa", 45000]
    
]

# %%
pd.DataFrame(dataa)
coloum = ["Name","Age","City","Salary"]
pd.DataFrame(dataa,columns=coloum)
# Out:
#              Name  Age          City  Salary
# 0            john   24      New york   65412
# 1           Noman   38           USA   78400
# 2  Dennis Retchie   90  South africa   45000

# %%
new_data = {
    "Name" : ["Sohan", "Krishana", "Dev", "Rohit"],
    "Age" :  [23, 54, 34, 35],
    "City" : ["Delhi","Gurjrat", "Pune", "Usa"],
    "Salary" : [4500, 4586, 1245, 6963]
}

# %%
df = pd.DataFrame(new_data)
print(df)
# Out:
#        Name  Age     City  Salary
# 0     Sohan   23    Delhi    4500
# 1  Krishana   54  Gurjrat    4586
# 2       Dev   34     Pune    1245
# 3     Rohit   35      Usa    6963

# %%
df[["Name","City","Age"]]
# Out:
#        Name     City  Age
# 0     Sohan    Delhi   23
# 1  Krishana  Gurjrat   54
# 2       Dev     Pune   34
# 3     Rohit      Usa   35

# %%
df["Designation"] = ["Doctor","Engineer","Professor","civil Engineer"]

# %%
df
# Out:
#        Name  Age     City  Salary     Designation
# 0     Sohan   23    Delhi    4500          Doctor
# 1  Krishana   54  Gurjrat    4586        Engineer
# 2       Dev   34     Pune    1245       Professor
# 3     Rohit   35      Usa    6963  civil Engineer

# %%
df2
# Out:
#       Name  Age      City  Salary
# 0    jonny   23     Delhi   65000
# 1     Anna   45   Mumbhai    4500
# 2    Rahul   34  Banglore    7800
# 3  krishna   24  New york   45820

# %%
df2 ["Work Experience"] = [8,6,2,6]

# %%
df2
# Out:
#    Age  Work Experience
# 0   23                8
# 1   45                6
# 2   34                2
# 3   24                6

# %%
#df2[['Name',"City","Age"]]

# %%
df2
# Out:
#    Age  Work Experience
# 0   23                8
# 1   45                6
# 2   34                2
# 3   24                6

# %%
df2.drop("Name",axis = 1, inplace=True)  #this work function parmanent delet coloum

# %%
df2
# Out:
#    Age  Work Experience
# 0   23                8
# 1   45                6
# 2   34                2
# 3   24                6

# %%
df
# Out:
#        Name  Age     City  Salary     Designation
# 0     Sohan   23    Delhi    4500          Doctor
# 1  Krishana   54  Gurjrat    4586        Engineer
# 2       Dev   34     Pune    1245       Professor
# 3     Rohit   35      Usa    6963  civil Engineer

# %%
df.drop(0,axis = 0) # removing a row
# Out:
#        Name  Age     City  Salary
# 1  Krishana   54  Gurjrat    4586
# 2       Dev   34     Pune    1245
# 3     Rohit   35      Usa    6963

# %%
df
# Out:
#        Name  Age     City  Salary
# 0     Sohan   23    Delhi    4500
# 1  Krishana   54  Gurjrat    4586
# 2       Dev   34     Pune    1245
# 3     Rohit   35      Usa    6963

# %% [markdown]
# Selecting Rows

# %%
df
# Out:
#        Name  Age     City  Salary
# 0     Sohan   23    Delhi    4500
# 1  Krishana   54  Gurjrat    4586
# 2       Dev   34     Pune    1245
# 3     Rohit   35      Usa    6963

# %%
df.loc[[0,1]]
# Out:
#        Name  Age     City  Salary
# 0     Sohan   23    Delhi    4500
# 1  Krishana   54  Gurjrat    4586

# %% [markdown]
# selecting subsets of rows abd columns

# %%
df.loc[[0,1]] [["City","Salary"]]
# Out:
#       City  Salary
# 0    Delhi    4500
# 1  Gurjrat    4586

# %%
df.loc[[1,2]] [["Name","Age"]]
# Out:
#        Name  Age
# 1  Krishana   54
# 2       Dev   34

# %% [markdown]
# Conditionl selection

# %%
df
# Out:
#        Name  Age     City  Salary
# 0     Sohan   23    Delhi    4500
# 1  Krishana   54  Gurjrat    4586
# 2       Dev   34     Pune    1245
# 3     Rohit   35      Usa    6963

# %%
df[df["Age"] > 30]
# Out:
#        Name  Age     City  Salary
# 1  Krishana   54  Gurjrat    4586
# 2       Dev   34     Pune    1245
# 3     Rohit   35      Usa    6963

# %%
df[(df["Age"] >30) & (df["City"] == "Pune")]
# Out:
#   Name  Age  City  Salary
# 2  Dev   34  Pune    1245
